# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df = pd.read_csv("breast-cancer.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
# to find null value
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.drop(['Unnamed: 32'], axis = 1 ,inplace=True)

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.shape
# Out:
# (569, 32)

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
sns.countplot(df['diagnosis'],label='count')
plt.show()

# %%
df.dtypes         # only one is object
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
df['diagnosis']=df['diagnosis'].map({'B':0,'M':1})

# %%
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
x = df.iloc[:,2:].values
y = df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=.2, random_state=12)

# %%
from sklearn.preprocessing import StandardScaler

std = StandardScaler()

# %%
std_train = std.fit_transform(x_train)
std_test = std.transform(x_test)

# %%
std_train.shape
# Out:
# (455, 30)

# %%
std_test.shape
# Out:
# (114, 30)

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(criterion = 'gini', random_state = 12)

dt.fit(std_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=12)

# %%
dt_train_score = dt.score(std_train,y_train)

dt_train_score
# Out:
# 1.0

# %%
dt_test_score = dt.score(std_test,y_test)

dt_test_score
# Out:
# 0.9473684210526315

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,dt.predict(std_test))
# Out:
# array([[64,  2],
#        [ 4, 44]], dtype=int64)

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators = 10 ,random_state=12)

rf.fit(std_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=12)

# %%
rf_train_score = rf.score(std_train,y_train)

rf_train_score
# Out:
# 0.9956043956043956

# %%
rf_test_score = rf.score(std_test,y_test)

rf_test_score
# Out:
# 0.9298245614035088

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,rf.predict(std_test))
# Out:
# array([[64,  2],
#        [ 6, 42]], dtype=int64)

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC

# %%
clf = SVC(kernel = 'linear',C=10)

clf.fit(std_train,y_train)
# Out:
# SVC(C=10, kernel='linear')

# %%
clf_train_score = clf.score(std_train,y_train)

clf_train_score
# Out:
# 0.9978021978021978

# %%
clf_test_score = clf.score(std_test,y_test)

clf_test_score
# Out:
# 0.956140350877193

# %%
confusion_matrix(y_test,clf.predict(std_test))
# Out:
# array([[65,  1],
#        [ 4, 44]], dtype=int64)

# %% [markdown]
# ### Best Above All

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log = LogisticRegression(random_state=12)

log.fit(std_train,y_train)
# Out:
# LogisticRegression(random_state=12)

# %%
log_train_score = log.score(std_train,y_train)

log_train_score
# Out:
# 0.989010989010989

# %%
log_test_score = log.score(std_test,y_test)

log_test_score
# Out:
# 0.9736842105263158

# %%
confusion_matrix(y_test,log.predict(std_test))
# Out:
# array([[66,  0],
#        [ 3, 45]], dtype=int64)
